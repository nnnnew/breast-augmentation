# %%
import pandas as pd
import numpy as np
import os


import keras
from keras.layers import Input, Dense, BatchNormalization, Activation, Dropout
from keras.optimizers import Adam
from keras.models import Model

from keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard

# %%
# Init params and helpers

# %%
model_tag = '01'
data_dir = '../data/'
cleaned_csv_file_name = 'cleaned.csv'
models_dir = './models'
logs_dir = './logs/'

num_k = 10

# %%
kfold_data_dir = '../data/k-fold/'
file_list = os.listdir(kfold_data_dir)
print(len(file_list))

num_k = int(len(file_list) / 2)
print(f'Number of K is {num_k}')

file_train_start = 'train'
file_test_start = 'test'
# Out:
# 20
# Number of K is 10

# %%
# define features and classes

# %%
predict_class_right = ['PostOp-SNR',  'PostOp-CNR',  'PostOp-BWR', 'PostOp-BHR',
                       'PostOp-IMFR',  'PostOp-AreRW', 'PostOp-AreRH']

predict_class_left = [ 'PostOp-SNL',  'PostOp-CNL', 'PostOp-BWL',
                      'PostOp-BHL',  'PostOp-IMFL','PostOp-AreLW', 'PostOp-AreLH']

predict_post_id = ['PostOp-ID']

feature_left = ['PreOp-SNL', 'PreOp-CNL', 'PreOp-BWL', 'PreOp-BHL', 'PreOp-IMFL', 'PreOp-AreLW',
                'PreOp-AreLH', 'PreOp-ID', 'ImplantLeft']

feature_right = ['PreOp-SNR', 'PreOp-CNR', 'PreOp-BWR', 'PreOp-BHR', 'PreOp-IMFR', 'PreOp-AreRW',
                'PreOp-AreRH', 'PreOp-ID', 'ImplantRight']

# %%
# Check diractory

# %%
if not os.path.exists(os.path.join(models_dir, model_tag)):
    os.mkdir(os.path.join(models_dir, model_tag))
    
if not os.path.exists(os.path.join(logs_dir, model_tag)):
    os.mkdir(os.path.join(logs_dir, model_tag))
    
for predict_class in predict_class_right+predict_class_left+predict_post_id:
    if not os.path.exists(os.path.join(models_dir, model_tag, predict_class)):
        os.mkdir(os.path.join(models_dir, model_tag, predict_class))
        
for predict_class in predict_class_right+predict_class_left+predict_post_id:
    if not os.path.exists(os.path.join(logs_dir, model_tag, predict_class)):
        os.mkdir(os.path.join(logs_dir, model_tag, predict_class))

# %%
def get_x_and_y(df: pd.DataFrame, x_head=[], y_head=[]):
    x, y = [], []
    
    for index, row in df.iterrows():
        x_temp = []
        for x_h in x_head:
            x_temp.append(row[x_h])
        x.append(x_temp)
        y.append(row[y_head[0]])
    
    return x, y

# %%
def create_model(feature_len):
    inp = Input(shape=(feature_len,))
    x = Dropout(0.25)(inp)
    x = Dense(512)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dense(256)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    output = Dense(1, activation='linear')(x)
    model = Model(inp, output)
    
    loss = 'mse'
    
    model.compile(optimizer=Adam(1e-4),
                  loss=loss)
    return model

# %%
def get_callbacks(model_path, log_path):
    
#     er = EarlyStopping(monitor="val_loss", mode="min", patience=20, verbose=1)
    checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True,  mode='min')
    tb = TensorBoard(log_path)
    return [checkpoint, tb]

# %%
def get_accuracy(model, x, y):
    result = model.predict(x)
    sum = 0
    for r, y in zip(result, y):
        sum += abs(r - y)
    return (sum / len(x))[0]

# %%
accuracies = []

prediction_tag = 'PostOp-SNL'
for k in range(num_k):
    train_df = pd.read_csv(os.path.join(kfold_data_dir, f'{file_train_start}_{k}.csv',)).dropna()
    test_df = pd.read_csv(os.path.join(kfold_data_dir, f'{file_test_start}_{k}.csv')).dropna()
    
    # Create right side model
    
    x_train, y_train = get_x_and_y(train_df, feature_left, [prediction_tag])
    x_test, y_test = get_x_and_y(test_df, feature_left, [prediction_tag])
    
    x_train = np.array(x_train)
    y_train = np.array(y_train)
    
    x_test = np.array(x_test)
    y_test = np.array(y_test)
    
    model_path = os.path.join(os.path.join(models_dir, model_tag, prediction_tag, 'model_' + str(k) + '.h5'))
    
    if not os.path.exists(os.path.join(logs_dir, model_tag, prediction_tag, str(k))):
        os.mkdir(os.path.join(logs_dir, model_tag, prediction_tag, str(k)))
        
    log_path = os.path.join(os.path.join(logs_dir, model_tag, prediction_tag, str(k)))
    
    
    model = create_model(len(x_train[0]))
    history = model.fit(x_train, y_train,
                        batch_size=8,
                        epochs=1000,
                        callbacks=get_callbacks(model_path, log_path),
                        validation_data=[x_test, y_test])

    model.fit(x_train, y_train)
    model.load_weights(model_path)
    accuracies.append(get_accuracy(model, x_test, y_test))

# print(sum(result) / len(result))
# Out:
# Train on 92 samples, validate on 8 samples
# Epoch 1/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 394.4612 - val_loss: 365.4557
#
# Epoch 00001: val_loss improved from inf to 365.45572, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 2/1000
# 92/92 [==============================] - 0s 286us/step - loss: 385.1134 - val_loss: 364.1573
#
# Epoch 00002: val_loss improved from 365.45572 to 364.15732, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 3/1000
# 92/92 [==============================] - 0s 298us/step - loss: 378.5639 - val_loss: 363.8041
#
# Epoch 00003: val_loss improved from 364.15732 to 363.80408, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 4/1000
# 92/92 [==============================] - 0s 325us/step - loss: 371.3259 - val_loss: 351.9925
#
# Epoch 00004: val_loss improved from 363.80408 to 351.99246, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 5/1000
# 92/92 [==============================] - 0s 298us/step - loss: 362.6319 - val_loss: 343.6284
#
# Epoch 00005: val_loss improved from 351.99246 to 343.62842, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 6/1000
# 92/92 [==============================] - 0s 305us/step - loss: 358.8044 - val_loss: 341.2358
#
# Epoch 00006: val_loss improved from 343.62842 to 341.23584, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 7/1000
# 92/92 [==============================] - 0s 317us/step - loss: 351.6947 - val_loss: 337.6893
#
# Epoch 00007: val_loss improved from 341.23584 to 337.68927, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 8/1000
# 92/92 [==============================] - 0s 287us/step - loss: 345.8491 - val_loss: 325.9125
#
# Epoch 00008: val_loss improved from 337.68927 to 325.91248, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 9/1000
# 92/92 [==============================] - 0s 306us/step - loss: 339.9284 - val_loss: 314.9560
#
# Epoch 00009: val_loss improved from 325.91248 to 314.95599, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 10/1000
# 92/92 [==============================] - 0s 307us/step - loss: 331.0427 - val_loss: 310.3211
#
# Epoch 00010: val_loss improved from 314.95599 to 310.32111, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 11/1000
# 92/92 [==============================] - 0s 296us/step - loss: 331.5976 - val_loss: 298.6454
#
# Epoch 00011: val_loss improved from 310.32111 to 298.64542, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 12/1000
# 92/92 [==============================] - 0s 289us/step - loss: 323.1834 - val_loss: 293.0172
#
# Epoch 00012: val_loss improved from 298.64542 to 293.01715, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 13/1000
# 92/92 [==============================] - 0s 308us/step - loss: 319.4389 - val_loss: 282.6484
#
# Epoch 00013: val_loss improved from 293.01715 to 282.64841, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 14/1000
# 92/92 [==============================] - 0s 314us/step - loss: 313.4849 - val_loss: 271.4900
#
# Epoch 00014: val_loss improved from 282.64841 to 271.48996, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 15/1000
# 92/92 [==============================] - 0s 294us/step - loss: 307.2836 - val_loss: 263.6430
#
# Epoch 00015: val_loss improved from 271.48996 to 263.64304, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 16/1000
# 92/92 [==============================] - 0s 311us/step - loss: 302.8727 - val_loss: 255.8984
#
# Epoch 00016: val_loss improved from 263.64304 to 255.89844, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 17/1000
# 92/92 [==============================] - 0s 309us/step - loss: 295.5800 - val_loss: 252.0631
#
# Epoch 00017: val_loss improved from 255.89844 to 252.06313, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 18/1000
# 92/92 [==============================] - 0s 312us/step - loss: 290.8480 - val_loss: 248.5190
#
# Epoch 00018: val_loss improved from 252.06313 to 248.51904, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 19/1000
# 92/92 [==============================] - 0s 297us/step - loss: 284.2957 - val_loss: 242.5145
#
# Epoch 00019: val_loss improved from 248.51904 to 242.51454, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 20/1000
# 92/92 [==============================] - 0s 291us/step - loss: 279.1950 - val_loss: 238.2133
#
# Epoch 00020: val_loss improved from 242.51454 to 238.21329, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 21/1000
# 92/92 [==============================] - 0s 311us/step - loss: 279.7825 - val_loss: 232.5419
#
# Epoch 00021: val_loss improved from 238.21329 to 232.54190, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 22/1000
# 92/92 [==============================] - 0s 316us/step - loss: 275.6749 - val_loss: 225.4010
#
# Epoch 00022: val_loss improved from 232.54190 to 225.40097, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 23/1000
# 92/92 [==============================] - 0s 332us/step - loss: 265.7450 - val_loss: 221.5818
#
# Epoch 00023: val_loss improved from 225.40097 to 221.58185, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 24/1000
# 92/92 [==============================] - 0s 306us/step - loss: 262.0020 - val_loss: 218.1337
#
# Epoch 00024: val_loss improved from 221.58185 to 218.13367, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 25/1000
# 92/92 [==============================] - 0s 287us/step - loss: 255.5405 - val_loss: 211.0453
#
# Epoch 00025: val_loss improved from 218.13367 to 211.04526, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 26/1000
# 92/92 [==============================] - 0s 292us/step - loss: 250.3511 - val_loss: 204.8812
#
# Epoch 00026: val_loss improved from 211.04526 to 204.88123, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 27/1000
# 92/92 [==============================] - 0s 305us/step - loss: 247.5824 - val_loss: 197.8920
#
# Epoch 00027: val_loss improved from 204.88123 to 197.89200, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 28/1000
# 92/92 [==============================] - 0s 301us/step - loss: 240.0389 - val_loss: 196.3011
#
# Epoch 00028: val_loss improved from 197.89200 to 196.30106, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 29/1000
# 92/92 [==============================] - 0s 302us/step - loss: 244.0654 - val_loss: 190.2752
#
# Epoch 00029: val_loss improved from 196.30106 to 190.27521, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 30/1000
# 92/92 [==============================] - 0s 302us/step - loss: 238.6527 - val_loss: 181.4119
#
# Epoch 00030: val_loss improved from 190.27521 to 181.41190, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 31/1000
# 92/92 [==============================] - 0s 306us/step - loss: 227.1544 - val_loss: 179.7025
#
# Epoch 00031: val_loss improved from 181.41190 to 179.70245, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 32/1000
# 92/92 [==============================] - 0s 296us/step - loss: 230.1829 - val_loss: 174.4799
#
# Epoch 00032: val_loss improved from 179.70245 to 174.47992, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 33/1000
# 92/92 [==============================] - 0s 303us/step - loss: 224.8104 - val_loss: 171.6759
#
# Epoch 00033: val_loss improved from 174.47992 to 171.67595, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 34/1000
# 92/92 [==============================] - 0s 299us/step - loss: 214.7766 - val_loss: 168.7282
#
# Epoch 00034: val_loss improved from 171.67595 to 168.72818, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 35/1000
# 92/92 [==============================] - 0s 317us/step - loss: 211.7507 - val_loss: 167.5753
#
# Epoch 00035: val_loss improved from 168.72818 to 167.57532, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 36/1000
# 92/92 [==============================] - 0s 312us/step - loss: 204.6775 - val_loss: 164.4660
#
# Epoch 00036: val_loss improved from 167.57532 to 164.46600, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 37/1000
# 92/92 [==============================] - 0s 293us/step - loss: 207.1874 - val_loss: 159.6415
#
# Epoch 00037: val_loss improved from 164.46600 to 159.64153, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 38/1000
# 92/92 [==============================] - 0s 289us/step - loss: 205.1268 - val_loss: 155.2926
# Epoch 00038: val_loss improved from 159.64153 to 155.29263, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 39/1000
# 92/92 [==============================] - 0s 300us/step - loss: 197.7024 - val_loss: 150.9075
#
# Epoch 00039: val_loss improved from 155.29263 to 150.90750, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 40/1000
# 92/92 [==============================] - 0s 306us/step - loss: 192.1813 - val_loss: 145.8530
#
# Epoch 00040: val_loss improved from 150.90750 to 145.85304, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 41/1000
# 92/92 [==============================] - 0s 299us/step - loss: 189.2139 - val_loss: 139.5323
#
# Epoch 00041: val_loss improved from 145.85304 to 139.53235, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 42/1000
# 92/92 [==============================] - 0s 291us/step - loss: 188.9476 - val_loss: 132.7113
#
# Epoch 00042: val_loss improved from 139.53235 to 132.71133, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 43/1000
# 92/92 [==============================] - 0s 294us/step - loss: 180.6348 - val_loss: 129.3428
#
# Epoch 00043: val_loss improved from 132.71133 to 129.34279, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 44/1000
# 92/92 [==============================] - 0s 299us/step - loss: 182.5734 - val_loss: 124.7868
#
# Epoch 00044: val_loss improved from 129.34279 to 124.78681, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 45/1000
# 92/92 [==============================] - 0s 306us/step - loss: 179.5925 - val_loss: 121.2645
#
# Epoch 00045: val_loss improved from 124.78681 to 121.26453, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 46/1000
# 92/92 [==============================] - 0s 294us/step - loss: 169.4942 - val_loss: 116.4531
#
# Epoch 00046: val_loss improved from 121.26453 to 116.45310, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 47/1000
# 92/92 [==============================] - 0s 293us/step - loss: 174.5506 - val_loss: 109.7876
#
# Epoch 00047: val_loss improved from 116.45310 to 109.78760, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 48/1000
# 92/92 [==============================] - 0s 299us/step - loss: 165.4024 - val_loss: 104.4725
#
# Epoch 00048: val_loss improved from 109.78760 to 104.47255, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 49/1000
# 92/92 [==============================] - 0s 289us/step - loss: 161.3053 - val_loss: 105.0595
#
# Epoch 00049: val_loss did not improve from 104.47255
# Epoch 50/1000
# 92/92 [==============================] - 0s 293us/step - loss: 167.9394 - val_loss: 101.3092
#
# Epoch 00050: val_loss improved from 104.47255 to 101.30920, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 51/1000
# 92/92 [==============================] - 0s 287us/step - loss: 159.3565 - val_loss: 98.2575
#
# Epoch 00051: val_loss improved from 101.30920 to 98.25748, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 52/1000
# 92/92 [==============================] - 0s 305us/step - loss: 160.0685 - val_loss: 97.0030
#
# Epoch 00052: val_loss improved from 98.25748 to 97.00304, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 53/1000
# 92/92 [==============================] - 0s 306us/step - loss: 152.5529 - val_loss: 92.0723
#
# Epoch 00053: val_loss improved from 97.00304 to 92.07231, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 54/1000
# 92/92 [==============================] - 0s 290us/step - loss: 141.5315 - val_loss: 88.8089
#
# Epoch 00054: val_loss improved from 92.07231 to 88.80894, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 55/1000
# 92/92 [==============================] - 0s 311us/step - loss: 141.0411 - val_loss: 85.1954
#
# Epoch 00055: val_loss improved from 88.80894 to 85.19537, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 56/1000
# 92/92 [==============================] - 0s 297us/step - loss: 144.6986 - val_loss: 81.2819
#
# Epoch 00056: val_loss improved from 85.19537 to 81.28191, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 57/1000
# 92/92 [==============================] - 0s 303us/step - loss: 139.9341 - val_loss: 79.4420
#
# Epoch 00057: val_loss improved from 81.28191 to 79.44196, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 58/1000
# 92/92 [==============================] - 0s 288us/step - loss: 125.8274 - val_loss: 77.1758
#
# Epoch 00058: val_loss improved from 79.44196 to 77.17584, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 59/1000
# 92/92 [==============================] - 0s 311us/step - loss: 136.6195 - val_loss: 73.4767
#
# Epoch 00059: val_loss improved from 77.17584 to 73.47675, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 60/1000
# 92/92 [==============================] - 0s 308us/step - loss: 133.8627 - val_loss: 69.9099
#
# Epoch 00060: val_loss improved from 73.47675 to 69.90985, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 61/1000
# 92/92 [==============================] - 0s 297us/step - loss: 124.7688 - val_loss: 68.0941
#
# Epoch 00061: val_loss improved from 69.90985 to 68.09406, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 62/1000
# 92/92 [==============================] - 0s 294us/step - loss: 126.6939 - val_loss: 67.9230
#
# Epoch 00062: val_loss improved from 68.09406 to 67.92297, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 63/1000
# 92/92 [==============================] - 0s 312us/step - loss: 121.5785 - val_loss: 64.5122
#
# Epoch 00063: val_loss improved from 67.92297 to 64.51224, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 64/1000
# 92/92 [==============================] - 0s 284us/step - loss: 116.3654 - val_loss: 63.1564
#
# Epoch 00064: val_loss improved from 64.51224 to 63.15636, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 65/1000
# 92/92 [==============================] - 0s 310us/step - loss: 122.8154 - val_loss: 63.4367
#
# Epoch 00065: val_loss did not improve from 63.15636
# Epoch 66/1000
# 92/92 [==============================] - 0s 303us/step - loss: 111.0293 - val_loss: 58.7826
#
# Epoch 00066: val_loss improved from 63.15636 to 58.78258, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 67/1000
# 92/92 [==============================] - 0s 292us/step - loss: 114.1012 - val_loss: 54.0180
#
# Epoch 00067: val_loss improved from 58.78258 to 54.01803, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 68/1000
# 92/92 [==============================] - 0s 286us/step - loss: 110.0162 - val_loss: 51.4225
#
# Epoch 00068: val_loss improved from 54.01803 to 51.42246, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 69/1000
# 92/92 [==============================] - 0s 301us/step - loss: 105.8208 - val_loss: 48.7989
#
# Epoch 00069: val_loss improved from 51.42246 to 48.79889, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 70/1000
# 92/92 [==============================] - 0s 302us/step - loss: 96.4560 - val_loss: 46.5762
#
# Epoch 00070: val_loss improved from 48.79889 to 46.57616, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 71/1000
# 92/92 [==============================] - 0s 288us/step - loss: 98.1199 - val_loss: 45.9966
#
# Epoch 00071: val_loss improved from 46.57616 to 45.99657, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 72/1000
# 92/92 [==============================] - 0s 292us/step - loss: 101.1108 - val_loss: 46.0608
#
# Epoch 00072: val_loss did not improve from 45.99657
# Epoch 73/1000
# 92/92 [==============================] - 0s 313us/step - loss: 97.9709 - val_loss: 43.8897
#
# Epoch 00073: val_loss improved from 45.99657 to 43.88967, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 74/1000
# 92/92 [==============================] - 0s 295us/step - loss: 99.5009 - val_loss: 41.7858
#
# Epoch 00074: val_loss improved from 43.88967 to 41.78583, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 75/1000
# 92/92 [==============================] - 0s 289us/step - loss: 92.3893 - val_loss: 41.5344
#
# Epoch 00075: val_loss improved from 41.78583 to 41.53443, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 76/1000
# 92/92 [==============================] - 0s 291us/step - loss: 90.1503 - val_loss: 40.8064
#
# Epoch 00076: val_loss improved from 41.53443 to 40.80639, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 77/1000
# 92/92 [==============================] - 0s 299us/step - loss: 80.9925 - val_loss: 37.7408
#
# Epoch 00077: val_loss improved from 40.80639 to 37.74075, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 78/1000
# 92/92 [==============================] - 0s 305us/step - loss: 87.8201 - val_loss: 36.0175
#
# Epoch 00078: val_loss improved from 37.74075 to 36.01753, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 79/1000
# 92/92 [==============================] - 0s 292us/step - loss: 83.5973 - val_loss: 33.6670
#
# Epoch 00079: val_loss improved from 36.01753 to 33.66703, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 80/1000
# 92/92 [==============================] - 0s 293us/step - loss: 84.6351 - val_loss: 31.7681
#
# Epoch 00080: val_loss improved from 33.66703 to 31.76806, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 81/1000
# 92/92 [==============================] - 0s 352us/step - loss: 81.1648 - val_loss: 29.0988
#
# Epoch 00081: val_loss improved from 31.76806 to 29.09878, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 82/1000
# 92/92 [==============================] - 0s 285us/step - loss: 70.1284 - val_loss: 25.7576
#
# Epoch 00082: val_loss improved from 29.09878 to 25.75759, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 83/1000
# 92/92 [==============================] - 0s 294us/step - loss: 81.6439 - val_loss: 24.4091
#
# Epoch 00083: val_loss improved from 25.75759 to 24.40915, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 84/1000
# 92/92 [==============================] - 0s 284us/step - loss: 77.2302 - val_loss: 23.9072
#
# Epoch 00084: val_loss improved from 24.40915 to 23.90716, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 85/1000
# 92/92 [==============================] - 0s 293us/step - loss: 72.5950 - val_loss: 23.6039
#
# Epoch 00085: val_loss improved from 23.90716 to 23.60387, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 86/1000
# 92/92 [==============================] - 0s 290us/step - loss: 67.3580 - val_loss: 21.8128
#
# Epoch 00086: val_loss improved from 23.60387 to 21.81279, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 87/1000
# 92/92 [==============================] - 0s 299us/step - loss: 68.9048 - val_loss: 20.6301
#
# Epoch 00087: val_loss improved from 21.81279 to 20.63012, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 88/1000
# 92/92 [==============================] - 0s 286us/step - loss: 67.7562 - val_loss: 20.3791
#
# Epoch 00088: val_loss improved from 20.63012 to 20.37908, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 89/1000
# 92/92 [==============================] - 0s 289us/step - loss: 66.6334 - val_loss: 19.9284
#
# Epoch 00089: val_loss improved from 20.37908 to 19.92836, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 90/1000
# 92/92 [==============================] - 0s 291us/step - loss: 65.0123 - val_loss: 19.3934
#
# Epoch 00090: val_loss improved from 19.92836 to 19.39343, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 91/1000
# 92/92 [==============================] - 0s 302us/step - loss: 57.9087 - val_loss: 17.3797
#
# Epoch 00091: val_loss improved from 19.39343 to 17.37967, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 92/1000
# 92/92 [==============================] - 0s 304us/step - loss: 59.3269 - val_loss: 17.5752
#
# Epoch 00092: val_loss did not improve from 17.37967
# Epoch 93/1000
# 92/92 [==============================] - 0s 310us/step - loss: 54.5742 - val_loss: 15.9466
#
# Epoch 00093: val_loss improved from 17.37967 to 15.94663, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 94/1000
# 92/92 [==============================] - 0s 303us/step - loss: 57.2666 - val_loss: 15.4361
#
# Epoch 00094: val_loss improved from 15.94663 to 15.43612, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 95/1000
# 92/92 [==============================] - 0s 293us/step - loss: 54.5283 - val_loss: 14.5757
#
# Epoch 00095: val_loss improved from 15.43612 to 14.57572, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 96/1000
# 92/92 [==============================] - 0s 304us/step - loss: 53.3599 - val_loss: 13.3742
#
# Epoch 00096: val_loss improved from 14.57572 to 13.37423, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 97/1000
# 92/92 [==============================] - 0s 289us/step - loss: 53.4212 - val_loss: 12.5877
#
# Epoch 00097: val_loss improved from 13.37423 to 12.58769, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 98/1000
# 92/92 [==============================] - 0s 312us/step - loss: 50.6491 - val_loss: 11.4343
#
# Epoch 00098: val_loss improved from 12.58769 to 11.43432, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 99/1000
# 92/92 [==============================] - 0s 288us/step - loss: 48.9862 - val_loss: 11.2403
#
# Epoch 00099: val_loss improved from 11.43432 to 11.24032, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 100/1000
# 92/92 [==============================] - 0s 288us/step - loss: 46.6946 - val_loss: 10.2655
#
# Epoch 00100: val_loss improved from 11.24032 to 10.26552, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 101/1000
# 92/92 [==============================] - 0s 331us/step - loss: 45.7657 - val_loss: 9.8656
#
# Epoch 00101: val_loss improved from 10.26552 to 9.86562, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 102/1000
# 92/92 [==============================] - 0s 353us/step - loss: 46.3882 - val_loss: 9.8118
#
# Epoch 00102: val_loss improved from 9.86562 to 9.81182, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 103/1000
# 92/92 [==============================] - 0s 404us/step - loss: 47.0629 - val_loss: 9.9388
#
# Epoch 00103: val_loss did not improve from 9.81182
# Epoch 104/1000
# 92/92 [==============================] - 0s 364us/step - loss: 40.1720 - val_loss: 8.7109
#
# Epoch 00104: val_loss improved from 9.81182 to 8.71089, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 105/1000
# 92/92 [==============================] - 0s 336us/step - loss: 47.4819 - val_loss: 9.7867
#
# Epoch 00105: val_loss did not improve from 8.71089
# Epoch 106/1000
# 92/92 [==============================] - 0s 331us/step - loss: 39.6440 - val_loss: 9.9339
#
# Epoch 00106: val_loss did not improve from 8.71089
# Epoch 107/1000
# 92/92 [==============================] - 0s 320us/step - loss: 40.9138 - val_loss: 10.0995
#
# Epoch 00107: val_loss did not improve from 8.71089
# Epoch 108/1000
# 92/92 [==============================] - 0s 327us/step - loss: 35.2192 - val_loss: 8.5598
#
# Epoch 00108: val_loss improved from 8.71089 to 8.55984, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 109/1000
# 92/92 [==============================] - 0s 295us/step - loss: 38.8479 - val_loss: 7.9985
#
# Epoch 00109: val_loss improved from 8.55984 to 7.99848, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 110/1000
# 92/92 [==============================] - 0s 305us/step - loss: 32.6231 - val_loss: 7.0804
#
# Epoch 00110: val_loss improved from 7.99848 to 7.08039, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 111/1000
# 92/92 [==============================] - 0s 303us/step - loss: 37.0228 - val_loss: 7.7861
#
# Epoch 00111: val_loss did not improve from 7.08039
# Epoch 112/1000
# 92/92 [==============================] - 0s 309us/step - loss: 43.4570 - val_loss: 9.5363
#
# Epoch 00112: val_loss did not improve from 7.08039
# Epoch 113/1000
# 92/92 [==============================] - 0s 328us/step - loss: 38.9224 - val_loss: 10.7324
#
# Epoch 00113: val_loss did not improve from 7.08039
# Epoch 114/1000
# 92/92 [==============================] - 0s 323us/step - loss: 34.1575 - val_loss: 10.3855
#
# Epoch 00114: val_loss did not improve from 7.08039
# Epoch 115/1000
# 92/92 [==============================] - 0s 329us/step - loss: 34.7203 - val_loss: 9.5459
#
# Epoch 00115: val_loss did not improve from 7.08039
# Epoch 116/1000
# 92/92 [==============================] - 0s 325us/step - loss: 27.1235 - val_loss: 6.7296
#
# Epoch 00116: val_loss improved from 7.08039 to 6.72955, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 117/1000
# 92/92 [==============================] - 0s 311us/step - loss: 25.7727 - val_loss: 4.9092
#
# Epoch 00117: val_loss improved from 6.72955 to 4.90918, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 118/1000
# 92/92 [==============================] - 0s 308us/step - loss: 27.1707 - val_loss: 4.3936
#
# Epoch 00118: val_loss improved from 4.90918 to 4.39358, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 119/1000
# 92/92 [==============================] - 0s 290us/step - loss: 24.1817 - val_loss: 3.4066
#
# Epoch 00119: val_loss improved from 4.39358 to 3.40658, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 120/1000
# 92/92 [==============================] - 0s 312us/step - loss: 22.6916 - val_loss: 2.1744
#
# Epoch 00120: val_loss improved from 3.40658 to 2.17443, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 121/1000
# 92/92 [==============================] - 0s 297us/step - loss: 25.7386 - val_loss: 1.7562
#
# Epoch 00121: val_loss improved from 2.17443 to 1.75616, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 122/1000
# 92/92 [==============================] - 0s 296us/step - loss: 23.5410 - val_loss: 1.5753
#
# Epoch 00122: val_loss improved from 1.75616 to 1.57535, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 123/1000
# 92/92 [==============================] - 0s 295us/step - loss: 23.1611 - val_loss: 1.4906
#
# Epoch 00123: val_loss improved from 1.57535 to 1.49058, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 124/1000
# 92/92 [==============================] - 0s 311us/step - loss: 24.1491 - val_loss: 1.4748
#
# Epoch 00124: val_loss improved from 1.49058 to 1.47479, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 125/1000
# 92/92 [==============================] - 0s 323us/step - loss: 24.9646 - val_loss: 1.5553
#
# Epoch 00125: val_loss did not improve from 1.47479
# Epoch 126/1000
# 92/92 [==============================] - 0s 321us/step - loss: 24.0829 - val_loss: 1.4943
#
# Epoch 00126: val_loss did not improve from 1.47479
# Epoch 127/1000
# 92/92 [==============================] - 0s 316us/step - loss: 23.2514 - val_loss: 1.8098
#
# Epoch 00127: val_loss did not improve from 1.47479
# Epoch 128/1000
# 92/92 [==============================] - 0s 316us/step - loss: 20.4225 - val_loss: 1.6901
#
# Epoch 00128: val_loss did not improve from 1.47479
# Epoch 129/1000
# 92/92 [==============================] - 0s 316us/step - loss: 18.8726 - val_loss: 1.3470
#
# Epoch 00129: val_loss improved from 1.47479 to 1.34698, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 130/1000
# 92/92 [==============================] - 0s 292us/step - loss: 16.8954 - val_loss: 1.0025
#
# Epoch 00130: val_loss improved from 1.34698 to 1.00255, saving model to ./models/01/PostOp-SNL/model_0.h5
# Epoch 131/1000
# 92/92 [==============================] - 0s 283us/step - loss: 19.8777 - val_loss: 1.0722
#
# Epoch 00131: val_loss did not improve from 1.00255
# Epoch 132/1000
# 92/92 [==============================] - 0s 319us/step - loss: 19.6999 - val_loss: 1.2433
#
# Epoch 00132: val_loss did not improve from 1.00255
# Epoch 133/1000
# 92/92 [==============================] - 0s 319us/step - loss: 18.0324 - val_loss: 1.1192
#
# Epoch 00133: val_loss did not improve from 1.00255
# Epoch 134/1000
# 92/92 [==============================] - 0s 336us/step - loss: 15.9277 - val_loss: 1.0383
#
# Epoch 00134: val_loss did not improve from 1.00255
# Epoch 135/1000
# 92/92 [==============================] - 0s 333us/step - loss: 17.5707 - val_loss: 1.0086
#
# Epoch 00135: val_loss did not improve from 1.00255
# Epoch 136/1000
# 92/92 [==============================] - 0s 336us/step - loss: 18.0704 - val_loss: 1.0843
#
# Epoch 00136: val_loss did not improve from 1.00255
# Epoch 137/1000
# 92/92 [==============================] - 0s 335us/step - loss: 17.3568 - val_loss: 1.2089
#
# Epoch 00137: val_loss did not improve from 1.00255
# Epoch 138/1000
# 92/92 [==============================] - 0s 329us/step - loss: 16.7734 - val_loss: 1.0472
#
# Epoch 00138: val_loss did not improve from 1.00255
# Epoch 139/1000
# 92/92 [==============================] - 0s 324us/step - loss: 13.6104 - val_loss: 1.1103
#
# Epoch 00139: val_loss did not improve from 1.00255
# Epoch 140/1000
# 92/92 [==============================] - 0s 316us/step - loss: 15.2708 - val_loss: 1.1552
#
# Epoch 00140: val_loss did not improve from 1.00255
# Epoch 141/1000
# 92/92 [==============================] - 0s 318us/step - loss: 15.0241 - val_loss: 1.1861
#
# Epoch 00141: val_loss did not improve from 1.00255
# Epoch 142/1000
# 92/92 [==============================] - 0s 306us/step - loss: 16.1364 - val_loss: 1.2183
#
# Epoch 00142: val_loss did not improve from 1.00255
# Epoch 143/1000
# 92/92 [==============================] - 0s 329us/step - loss: 15.5912 - val_loss: 1.6344
#
# Epoch 00143: val_loss did not improve from 1.00255
# Epoch 144/1000
# 92/92 [==============================] - 0s 324us/step - loss: 13.3866 - val_loss: 1.6857
#
# Epoch 00144: val_loss did not improve from 1.00255
# Epoch 145/1000
# 92/92 [==============================] - 0s 317us/step - loss: 13.1645 - val_loss: 1.5072
#
# Epoch 00145: val_loss did not improve from 1.00255
# Epoch 146/1000
# 92/92 [==============================] - 0s 325us/step - loss: 13.9300 - val_loss: 1.6025
#
# Epoch 00146: val_loss did not improve from 1.00255
# Epoch 147/1000
# 92/92 [==============================] - 0s 316us/step - loss: 12.7382 - val_loss: 1.1744
#
# Epoch 00147: val_loss did not improve from 1.00255
# Epoch 148/1000
# 92/92 [==============================] - 0s 330us/step - loss: 9.9154 - val_loss: 1.1532
#
# Epoch 00148: val_loss did not improve from 1.00255
# Epoch 149/1000
# 92/92 [==============================] - 0s 329us/step - loss: 11.5602 - val_loss: 1.1612
#
# Epoch 00149: val_loss did not improve from 1.00255
# Epoch 150/1000
# 92/92 [==============================] - 0s 323us/step - loss: 18.4764 - val_loss: 1.2402
#
# Epoch 00150: val_loss did not improve from 1.00255
# Epoch 00150: early stopping
# Epoch 1/1
# 92/92 [==============================] - 0s 97us/step - loss: 8.2758
# Train on 90 samples, validate on 10 samples
# Epoch 1/1000
# 90/90 [==============================] - 0s 5ms/step - loss: 363.3920 - val_loss: 340.6077
#
# Epoch 00001: val_loss improved from inf to 340.60771, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 2/1000
# 90/90 [==============================] - 0s 334us/step - loss: 354.0389 - val_loss: 338.1967
#
# Epoch 00002: val_loss improved from 340.60771 to 338.19671, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 3/1000
# 90/90 [==============================] - 0s 306us/step - loss: 346.4686 - val_loss: 336.8411
#
# Epoch 00003: val_loss improved from 338.19671 to 336.84105, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 4/1000
# 90/90 [==============================] - 0s 291us/step - loss: 343.2276 - val_loss: 334.5625
#
# Epoch 00004: val_loss improved from 336.84105 to 334.56246, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 5/1000
# 90/90 [==============================] - 0s 326us/step - loss: 336.3593 - val_loss: 325.4370
#
# Epoch 00005: val_loss improved from 334.56246 to 325.43702, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 6/1000
# 90/90 [==============================] - 0s 311us/step - loss: 330.2218 - val_loss: 319.9886
#
# Epoch 00006: val_loss improved from 325.43702 to 319.98864, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 7/1000
# 90/90 [==============================] - 0s 334us/step - loss: 324.7713 - val_loss: 318.1632
#
# Epoch 00007: val_loss improved from 319.98864 to 318.16318, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 8/1000
# 90/90 [==============================] - 0s 334us/step - loss: 318.0540 - val_loss: 315.0167
#
# Epoch 00008: val_loss improved from 318.16318 to 315.01672, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 9/1000
# 90/90 [==============================] - 0s 309us/step - loss: 311.9193 - val_loss: 312.9914
#
# Epoch 00009: val_loss improved from 315.01672 to 312.99136, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 10/1000
# 90/90 [==============================] - 0s 313us/step - loss: 308.5395 - val_loss: 306.7955
#
# Epoch 00010: val_loss improved from 312.99136 to 306.79554, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 11/1000
# 90/90 [==============================] - 0s 349us/step - loss: 299.3973 - val_loss: 302.9375
#
# Epoch 00011: val_loss improved from 306.79554 to 302.93749, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 12/1000
# 90/90 [==============================] - 0s 332us/step - loss: 296.2529 - val_loss: 296.3081
#
# Epoch 00012: val_loss improved from 302.93749 to 296.30815, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 13/1000
# 90/90 [==============================] - 0s 319us/step - loss: 295.8833 - val_loss: 293.8298
#
# Epoch 00013: val_loss improved from 296.30815 to 293.82975, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 14/1000
# 90/90 [==============================] - 0s 329us/step - loss: 290.6902 - val_loss: 284.7023
#
# Epoch 00014: val_loss improved from 293.82975 to 284.70226, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 15/1000
# 90/90 [==============================] - 0s 314us/step - loss: 286.6209 - val_loss: 275.2959
#
# Epoch 00015: val_loss improved from 284.70226 to 275.29592, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 16/1000
# 90/90 [==============================] - 0s 306us/step - loss: 275.0074 - val_loss: 272.6779
#
# Epoch 00016: val_loss improved from 275.29592 to 272.67788, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 17/1000
# 90/90 [==============================] - 0s 334us/step - loss: 270.7656 - val_loss: 269.1665
#
# Epoch 00017: val_loss improved from 272.67788 to 269.16653, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 18/1000
# 90/90 [==============================] - 0s 322us/step - loss: 269.2825 - val_loss: 260.4763
#
# Epoch 00018: val_loss improved from 269.16653 to 260.47629, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 19/1000
# 90/90 [==============================] - 0s 325us/step - loss: 261.7378 - val_loss: 255.4810
#
# Epoch 00019: val_loss improved from 260.47629 to 255.48099, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 20/1000
# 90/90 [==============================] - 0s 319us/step - loss: 257.3489 - val_loss: 253.7310
#
# Epoch 00020: val_loss improved from 255.48099 to 253.73095, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 21/1000
# 90/90 [==============================] - 0s 305us/step - loss: 253.0698 - val_loss: 247.1703
#
# Epoch 00021: val_loss improved from 253.73095 to 247.17033, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 22/1000
# 90/90 [==============================] - 0s 307us/step - loss: 249.8819 - val_loss: 238.3715
#
# Epoch 00022: val_loss improved from 247.17033 to 238.37148, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 23/1000
# 90/90 [==============================] - 0s 291us/step - loss: 244.2137 - val_loss: 232.9402
#
# Epoch 00023: val_loss improved from 238.37148 to 232.94022, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 24/1000
# 90/90 [==============================] - 0s 304us/step - loss: 242.9390 - val_loss: 231.4105
#
# Epoch 00024: val_loss improved from 232.94022 to 231.41054, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 25/1000
# 90/90 [==============================] - 0s 464us/step - loss: 236.7803 - val_loss: 228.0259
#
# Epoch 00025: val_loss improved from 231.41054 to 228.02595, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 26/1000
# 90/90 [==============================] - 0s 301us/step - loss: 232.4143 - val_loss: 219.2848
#
# Epoch 00026: val_loss improved from 228.02595 to 219.28479, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 27/1000
# 90/90 [==============================] - 0s 321us/step - loss: 223.5646 - val_loss: 222.7662
#
# Epoch 00027: val_loss did not improve from 219.28479
# Epoch 28/1000
# 90/90 [==============================] - 0s 322us/step - loss: 220.5327 - val_loss: 226.7613
#
# Epoch 00028: val_loss did not improve from 219.28479
# Epoch 29/1000
# 90/90 [==============================] - 0s 331us/step - loss: 226.2096 - val_loss: 218.1230
#
# Epoch 00029: val_loss improved from 219.28479 to 218.12304, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 30/1000
# 90/90 [==============================] - 0s 315us/step - loss: 221.4488 - val_loss: 217.9536
#
# Epoch 00030: val_loss improved from 218.12304 to 217.95356, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 31/1000
# 90/90 [==============================] - 0s 305us/step - loss: 211.5622 - val_loss: 212.9443
#
# Epoch 00031: val_loss improved from 217.95356 to 212.94429, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 32/1000
# 90/90 [==============================] - 0s 303us/step - loss: 206.5345 - val_loss: 206.0190
#
# Epoch 00032: val_loss improved from 212.94429 to 206.01900, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 33/1000
# 90/90 [==============================] - 0s 301us/step - loss: 204.4702 - val_loss: 203.1761
#
# Epoch 00033: val_loss improved from 206.01900 to 203.17609, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 34/1000
# 90/90 [==============================] - 0s 310us/step - loss: 199.2494 - val_loss: 194.6130
#
# Epoch 00034: val_loss improved from 203.17609 to 194.61302, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 35/1000
# 90/90 [==============================] - 0s 314us/step - loss: 197.5369 - val_loss: 189.3181
#
# Epoch 00035: val_loss improved from 194.61302 to 189.31813, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 36/1000
# 90/90 [==============================] - 0s 334us/step - loss: 191.6478 - val_loss: 187.1205
#
# Epoch 00036: val_loss improved from 189.31813 to 187.12048, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 37/1000
# 90/90 [==============================] - 0s 317us/step - loss: 188.8181 - val_loss: 178.4191
#
# Epoch 00037: val_loss improved from 187.12048 to 178.41906, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 38/1000
# 90/90 [==============================] - 0s 323us/step - loss: 175.7317 - val_loss: 174.8542
#
# Epoch 00038: val_loss improved from 178.41906 to 174.85421, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 39/1000
# 90/90 [==============================] - 0s 315us/step - loss: 181.6087 - val_loss: 172.1714
#
# Epoch 00039: val_loss improved from 174.85421 to 172.17141, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 40/1000
# 90/90 [==============================] - 0s 322us/step - loss: 178.7029 - val_loss: 164.9950
#
# Epoch 00040: val_loss improved from 172.17141 to 164.99498, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 41/1000
# 90/90 [==============================] - 0s 348us/step - loss: 170.6941 - val_loss: 159.0615
#
# Epoch 00041: val_loss improved from 164.99498 to 159.06148, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 42/1000
# 90/90 [==============================] - 0s 325us/step - loss: 171.4724 - val_loss: 155.6019
#
# Epoch 00042: val_loss improved from 159.06148 to 155.60186, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 43/1000
# 90/90 [==============================] - 0s 309us/step - loss: 171.1614 - val_loss: 152.2822
#
# Epoch 00043: val_loss improved from 155.60186 to 152.28215, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 44/1000
# 90/90 [==============================] - 0s 300us/step - loss: 164.4252 - val_loss: 148.7319
#
# Epoch 00044: val_loss improved from 152.28215 to 148.73195, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 45/1000
# 90/90 [==============================] - 0s 315us/step - loss: 159.8024 - val_loss: 144.3635
#
# Epoch 00045: val_loss improved from 148.73195 to 144.36354, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 46/1000
# 90/90 [==============================] - 0s 315us/step - loss: 151.2570 - val_loss: 144.6145
#
# Epoch 00046: val_loss did not improve from 144.36354
# Epoch 47/1000
# 90/90 [==============================] - 0s 323us/step - loss: 151.0275 - val_loss: 137.6210
#
# Epoch 00047: val_loss improved from 144.36354 to 137.62103, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 48/1000
# 90/90 [==============================] - 0s 331us/step - loss: 149.2423 - val_loss: 131.3300
#
# Epoch 00048: val_loss improved from 137.62103 to 131.33000, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 49/1000
# 90/90 [==============================] - 0s 334us/step - loss: 147.2784 - val_loss: 129.4124
#
# Epoch 00049: val_loss improved from 131.33000 to 129.41241, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 50/1000
# 90/90 [==============================] - 0s 318us/step - loss: 135.8010 - val_loss: 126.8082
# Epoch 00050: val_loss improved from 129.41241 to 126.80818, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 51/1000
# 90/90 [==============================] - 0s 319us/step - loss: 141.3581 - val_loss: 123.9834
#
# Epoch 00051: val_loss improved from 126.80818 to 123.98339, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 52/1000
# 90/90 [==============================] - 0s 305us/step - loss: 136.4203 - val_loss: 119.1771
#
# Epoch 00052: val_loss improved from 123.98339 to 119.17708, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 53/1000
# 90/90 [==============================] - 0s 295us/step - loss: 131.1825 - val_loss: 115.7063
#
# Epoch 00053: val_loss improved from 119.17708 to 115.70629, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 54/1000
# 90/90 [==============================] - 0s 314us/step - loss: 131.0454 - val_loss: 108.4342
#
# Epoch 00054: val_loss improved from 115.70629 to 108.43423, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 55/1000
# 90/90 [==============================] - 0s 307us/step - loss: 124.2328 - val_loss: 106.8218
#
# Epoch 00055: val_loss improved from 108.43423 to 106.82181, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 56/1000
# 90/90 [==============================] - 0s 312us/step - loss: 129.0630 - val_loss: 104.0384
#
# Epoch 00056: val_loss improved from 106.82181 to 104.03842, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 57/1000
# 90/90 [==============================] - 0s 310us/step - loss: 123.2195 - val_loss: 99.4729
#
# Epoch 00057: val_loss improved from 104.03842 to 99.47289, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 58/1000
# 90/90 [==============================] - 0s 314us/step - loss: 121.7535 - val_loss: 96.8879
#
# Epoch 00058: val_loss improved from 99.47289 to 96.88793, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 59/1000
# 90/90 [==============================] - 0s 320us/step - loss: 122.5994 - val_loss: 91.2290
#
# Epoch 00059: val_loss improved from 96.88793 to 91.22898, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 60/1000
# 90/90 [==============================] - 0s 297us/step - loss: 116.4119 - val_loss: 87.9755
#
# Epoch 00060: val_loss improved from 91.22898 to 87.97554, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 61/1000
# 90/90 [==============================] - 0s 325us/step - loss: 109.4729 - val_loss: 82.5280
#
# Epoch 00061: val_loss improved from 87.97554 to 82.52796, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 62/1000
# 90/90 [==============================] - 0s 335us/step - loss: 109.3583 - val_loss: 81.7580
#
# Epoch 00062: val_loss improved from 82.52796 to 81.75797, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 63/1000
# 90/90 [==============================] - 0s 323us/step - loss: 104.7435 - val_loss: 81.0840
#
# Epoch 00063: val_loss improved from 81.75797 to 81.08398, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 64/1000
# 90/90 [==============================] - 0s 320us/step - loss: 107.4421 - val_loss: 75.0596
#
# Epoch 00064: val_loss improved from 81.08398 to 75.05956, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 65/1000
# 90/90 [==============================] - 0s 308us/step - loss: 105.4008 - val_loss: 68.5760
#
# Epoch 00065: val_loss improved from 75.05956 to 68.57605, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 66/1000
# 90/90 [==============================] - 0s 303us/step - loss: 97.2331 - val_loss: 69.7887
#
# Epoch 00066: val_loss did not improve from 68.57605
# Epoch 67/1000
# 90/90 [==============================] - 0s 316us/step - loss: 101.2440 - val_loss: 70.2277
#
# Epoch 00067: val_loss did not improve from 68.57605
# Epoch 68/1000
# 90/90 [==============================] - 0s 324us/step - loss: 100.6799 - val_loss: 64.4888
#
# Epoch 00068: val_loss improved from 68.57605 to 64.48879, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 69/1000
# 90/90 [==============================] - 0s 321us/step - loss: 93.6968 - val_loss: 58.7310
#
# Epoch 00069: val_loss improved from 64.48879 to 58.73102, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 70/1000
# 90/90 [==============================] - 0s 308us/step - loss: 85.4996 - val_loss: 57.7918
#
# Epoch 00070: val_loss improved from 58.73102 to 57.79176, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 71/1000
# 90/90 [==============================] - 0s 309us/step - loss: 91.8684 - val_loss: 54.1233
#
# Epoch 00071: val_loss improved from 57.79176 to 54.12329, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 72/1000
# 90/90 [==============================] - 0s 318us/step - loss: 82.6367 - val_loss: 52.1379
#
# Epoch 00072: val_loss improved from 54.12329 to 52.13789, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 73/1000
# 90/90 [==============================] - 0s 313us/step - loss: 83.3391 - val_loss: 48.5775
#
# Epoch 00073: val_loss improved from 52.13789 to 48.57754, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 74/1000
# 90/90 [==============================] - 0s 320us/step - loss: 85.4884 - val_loss: 47.3400
#
# Epoch 00074: val_loss improved from 48.57754 to 47.33998, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 75/1000
# 90/90 [==============================] - 0s 302us/step - loss: 82.3495 - val_loss: 47.0328
#
# Epoch 00075: val_loss improved from 47.33998 to 47.03284, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 76/1000
# 90/90 [==============================] - 0s 303us/step - loss: 87.5573 - val_loss: 43.7667
#
# Epoch 00076: val_loss improved from 47.03284 to 43.76666, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 77/1000
# 90/90 [==============================] - 0s 312us/step - loss: 71.9569 - val_loss: 39.0936
#
# Epoch 00077: val_loss improved from 43.76666 to 39.09363, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 78/1000
# 90/90 [==============================] - 0s 315us/step - loss: 73.4712 - val_loss: 39.0069
#
# Epoch 00078: val_loss improved from 39.09363 to 39.00692, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 79/1000
# 90/90 [==============================] - 0s 311us/step - loss: 68.7995 - val_loss: 35.4456
#
# Epoch 00079: val_loss improved from 39.00692 to 35.44555, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 80/1000
# 90/90 [==============================] - 0s 310us/step - loss: 67.2723 - val_loss: 31.4350
#
# Epoch 00080: val_loss improved from 35.44555 to 31.43497, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 81/1000
# 90/90 [==============================] - 0s 318us/step - loss: 69.2545 - val_loss: 30.1303
#
# Epoch 00081: val_loss improved from 31.43497 to 30.13034, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 82/1000
# 90/90 [==============================] - 0s 309us/step - loss: 64.1884 - val_loss: 29.9521
#
# Epoch 00082: val_loss improved from 30.13034 to 29.95205, saving model to ./models/01/PostOp-SNL/model_1.h5
# Epoch 83/1000
# 90/90 [==============================] - 0s 303us/step - loss: 65.9328 - val_loss: 30.1618
#
# ...
# Epoch 142/1000
# 86/86 [==============================] - 0s 350us/step - loss: 15.8168 - val_loss: 14.1969
#
# Epoch 00142: val_loss improved from 15.22349 to 14.19689, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 143/1000
# 86/86 [==============================] - 0s 374us/step - loss: 13.1562 - val_loss: 12.7276
#
# Epoch 00143: val_loss improved from 14.19689 to 12.72760, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 144/1000
# 86/86 [==============================] - 0s 362us/step - loss: 12.6904 - val_loss: 13.2693
#
# Epoch 00144: val_loss did not improve from 12.72760
# Epoch 145/1000
# 86/86 [==============================] - 0s 349us/step - loss: 9.9326 - val_loss: 12.7407
#
# Epoch 00145: val_loss did not improve from 12.72760
# Epoch 146/1000
# 86/86 [==============================] - 0s 391us/step - loss: 10.2188 - val_loss: 12.2169
#
# Epoch 00146: val_loss improved from 12.72760 to 12.21693, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 147/1000
# 86/86 [==============================] - 0s 418us/step - loss: 11.2414 - val_loss: 12.5936
#
# Epoch 00147: val_loss did not improve from 12.21693
# Epoch 148/1000
# 86/86 [==============================] - 0s 423us/step - loss: 8.9409 - val_loss: 11.3015
#
# Epoch 00148: val_loss improved from 12.21693 to 11.30150, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 149/1000
# 86/86 [==============================] - 0s 377us/step - loss: 11.8746 - val_loss: 10.7045
#
# Epoch 00149: val_loss improved from 11.30150 to 10.70451, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 150/1000
# 86/86 [==============================] - 0s 356us/step - loss: 12.4924 - val_loss: 10.6413
#
# Epoch 00150: val_loss improved from 10.70451 to 10.64131, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 151/1000
# 86/86 [==============================] - 0s 333us/step - loss: 11.1502 - val_loss: 10.7646
#
# Epoch 00151: val_loss did not improve from 10.64131
# Epoch 152/1000
# 86/86 [==============================] - 0s 367us/step - loss: 8.0683 - val_loss: 10.2216
#
# Epoch 00152: val_loss improved from 10.64131 to 10.22163, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 153/1000
# 86/86 [==============================] - 0s 354us/step - loss: 7.4938 - val_loss: 9.7314
#
# Epoch 00153: val_loss improved from 10.22163 to 9.73144, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 154/1000
# 86/86 [==============================] - 0s 353us/step - loss: 8.7980 - val_loss: 9.9287
#
# Epoch 00154: val_loss did not improve from 9.73144
# Epoch 155/1000
# 86/86 [==============================] - 0s 366us/step - loss: 6.9502 - val_loss: 10.1374
#
# Epoch 00155: val_loss did not improve from 9.73144
# Epoch 156/1000
# 86/86 [==============================] - 0s 360us/step - loss: 12.6367 - val_loss: 11.0937
#
# Epoch 00156: val_loss did not improve from 9.73144
# Epoch 157/1000
# 86/86 [==============================] - 0s 385us/step - loss: 6.3534 - val_loss: 11.0532
#
# Epoch 00157: val_loss did not improve from 9.73144
# Epoch 158/1000
# 86/86 [==============================] - 0s 361us/step - loss: 9.1061 - val_loss: 10.0516
#
# Epoch 00158: val_loss did not improve from 9.73144
# Epoch 159/1000
# 86/86 [==============================] - 0s 386us/step - loss: 9.4990 - val_loss: 10.3775
#
# Epoch 00159: val_loss did not improve from 9.73144
# Epoch 160/1000
# 86/86 [==============================] - 0s 365us/step - loss: 8.0287 - val_loss: 9.1946
#
# Epoch 00160: val_loss improved from 9.73144 to 9.19462, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 161/1000
# 86/86 [==============================] - 0s 350us/step - loss: 8.8927 - val_loss: 9.6161
#
# Epoch 00161: val_loss did not improve from 9.19462
# Epoch 162/1000
# 86/86 [==============================] - 0s 359us/step - loss: 10.5620 - val_loss: 9.7436
#
# Epoch 00162: val_loss did not improve from 9.19462
# Epoch 163/1000
# 86/86 [==============================] - 0s 356us/step - loss: 5.9760 - val_loss: 8.2780
#
# Epoch 00163: val_loss improved from 9.19462 to 8.27800, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 164/1000
# 86/86 [==============================] - 0s 363us/step - loss: 6.8094 - val_loss: 8.3406
#
# Epoch 00164: val_loss did not improve from 8.27800
# Epoch 165/1000
# 86/86 [==============================] - 0s 365us/step - loss: 7.8250 - val_loss: 8.6608
#
# Epoch 00165: val_loss did not improve from 8.27800
# Epoch 166/1000
# 86/86 [==============================] - 0s 364us/step - loss: 7.4959 - val_loss: 8.7339
#
# Epoch 00166: val_loss did not improve from 8.27800
# Epoch 167/1000
# 86/86 [==============================] - 0s 387us/step - loss: 8.5611 - val_loss: 8.5695
#
# Epoch 00167: val_loss did not improve from 8.27800
# Epoch 168/1000
# 86/86 [==============================] - 0s 362us/step - loss: 5.2416 - val_loss: 8.1943
#
# Epoch 00168: val_loss improved from 8.27800 to 8.19429, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 169/1000
# 86/86 [==============================] - 0s 367us/step - loss: 8.7492 - val_loss: 8.4777
#
# Epoch 00169: val_loss did not improve from 8.19429
# Epoch 170/1000
# 86/86 [==============================] - 0s 369us/step - loss: 9.8329 - val_loss: 9.5123
#
# Epoch 00170: val_loss did not improve from 8.19429
# Epoch 171/1000
# 86/86 [==============================] - 0s 366us/step - loss: 5.5422 - val_loss: 9.2749
#
# Epoch 00171: val_loss did not improve from 8.19429
# Epoch 172/1000
# 86/86 [==============================] - 0s 389us/step - loss: 5.3362 - val_loss: 9.3869
#
# Epoch 00172: val_loss did not improve from 8.19429
# Epoch 173/1000
# 86/86 [==============================] - 0s 376us/step - loss: 11.0330 - val_loss: 9.9735
#
# Epoch 00173: val_loss did not improve from 8.19429
# Epoch 174/1000
# 86/86 [==============================] - 0s 388us/step - loss: 7.3259 - val_loss: 8.2278
#
# Epoch 00174: val_loss did not improve from 8.19429
# Epoch 175/1000
# 86/86 [==============================] - 0s 381us/step - loss: 6.4696 - val_loss: 8.4705
#
# Epoch 00175: val_loss did not improve from 8.19429
# Epoch 176/1000
# 86/86 [==============================] - 0s 380us/step - loss: 5.2612 - val_loss: 7.7176
#
# Epoch 00176: val_loss improved from 8.19429 to 7.71755, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 177/1000
# 86/86 [==============================] - 0s 359us/step - loss: 6.4681 - val_loss: 7.0223
#
# Epoch 00177: val_loss improved from 7.71755 to 7.02235, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 178/1000
# 86/86 [==============================] - 0s 359us/step - loss: 7.1217 - val_loss: 7.3020
#
# Epoch 00178: val_loss did not improve from 7.02235
# Epoch 179/1000
# 86/86 [==============================] - 0s 363us/step - loss: 6.7246 - val_loss: 7.3813
#
# Epoch 00179: val_loss did not improve from 7.02235
# Epoch 180/1000
# 86/86 [==============================] - 0s 391us/step - loss: 5.2355 - val_loss: 7.3100
#
# Epoch 00180: val_loss did not improve from 7.02235
# Epoch 181/1000
# 86/86 [==============================] - 0s 391us/step - loss: 6.7966 - val_loss: 7.2394
#
# Epoch 00181: val_loss did not improve from 7.02235
# Epoch 182/1000
# 86/86 [==============================] - 0s 380us/step - loss: 6.2756 - val_loss: 7.5510
#
# Epoch 00182: val_loss did not improve from 7.02235
# Epoch 183/1000
# 86/86 [==============================] - 0s 388us/step - loss: 4.2400 - val_loss: 7.5587
#
# Epoch 00183: val_loss did not improve from 7.02235
# Epoch 184/1000
# 86/86 [==============================] - 0s 404us/step - loss: 5.4806 - val_loss: 7.3487
#
# Epoch 00184: val_loss did not improve from 7.02235
# Epoch 185/1000
# 86/86 [==============================] - 0s 391us/step - loss: 4.6273 - val_loss: 6.9305
#
# Epoch 00185: val_loss improved from 7.02235 to 6.93050, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 186/1000
# 86/86 [==============================] - 0s 356us/step - loss: 5.6135 - val_loss: 6.0616
#
# Epoch 00186: val_loss improved from 6.93050 to 6.06162, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 187/1000
# 86/86 [==============================] - 0s 350us/step - loss: 5.8032 - val_loss: 6.1184
#
# Epoch 00187: val_loss did not improve from 6.06162
# Epoch 188/1000
# 86/86 [==============================] - 0s 355us/step - loss: 3.8451 - val_loss: 6.7166
#
# Epoch 00188: val_loss did not improve from 6.06162
# Epoch 189/1000
# 86/86 [==============================] - 0s 383us/step - loss: 4.7400 - val_loss: 6.2720
#
# Epoch 00189: val_loss did not improve from 6.06162
# Epoch 190/1000
# 86/86 [==============================] - 0s 382us/step - loss: 5.1455 - val_loss: 5.5748
#
# Epoch 00190: val_loss improved from 6.06162 to 5.57481, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 191/1000
# 86/86 [==============================] - 0s 360us/step - loss: 4.4012 - val_loss: 5.3169
#
# Epoch 00191: val_loss improved from 5.57481 to 5.31692, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 192/1000
# 86/86 [==============================] - 0s 327us/step - loss: 5.1946 - val_loss: 5.6946
#
# Epoch 00192: val_loss did not improve from 5.31692
# Epoch 193/1000
# 86/86 [==============================] - 0s 365us/step - loss: 4.4127 - val_loss: 5.9649
#
# Epoch 00193: val_loss did not improve from 5.31692
# Epoch 194/1000
# 86/86 [==============================] - 0s 360us/step - loss: 6.0961 - val_loss: 5.4741
#
# Epoch 00194: val_loss did not improve from 5.31692
# Epoch 195/1000
# 86/86 [==============================] - 0s 379us/step - loss: 5.9884 - val_loss: 5.3691
#
# Epoch 00195: val_loss did not improve from 5.31692
# Epoch 196/1000
# 86/86 [==============================] - 0s 378us/step - loss: 3.0589 - val_loss: 4.8980
#
# Epoch 00196: val_loss improved from 5.31692 to 4.89802, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 197/1000
# 86/86 [==============================] - 0s 344us/step - loss: 5.5117 - val_loss: 4.8433
#
# Epoch 00197: val_loss improved from 4.89802 to 4.84332, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 198/1000
# 86/86 [==============================] - 0s 357us/step - loss: 5.5500 - val_loss: 5.0655
#
# Epoch 00198: val_loss did not improve from 4.84332
# Epoch 199/1000
# 86/86 [==============================] - 0s 373us/step - loss: 3.4979 - val_loss: 4.9191
#
# Epoch 00199: val_loss did not improve from 4.84332
# Epoch 200/1000
# 86/86 [==============================] - 0s 387us/step - loss: 4.3917 - val_loss: 4.5695
#
# Epoch 00200: val_loss improved from 4.84332 to 4.56946, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 201/1000
# 86/86 [==============================] - 0s 363us/step - loss: 3.6774 - val_loss: 4.9017
#
# Epoch 00201: val_loss did not improve from 4.56946
# Epoch 202/1000
# 86/86 [==============================] - 0s 374us/step - loss: 2.7654 - val_loss: 5.2597
#
# Epoch 00202: val_loss did not improve from 4.56946
# Epoch 203/1000
# 86/86 [==============================] - 0s 387us/step - loss: 4.0616 - val_loss: 5.2751
#
# Epoch 00203: val_loss did not improve from 4.56946
# Epoch 204/1000
# 86/86 [==============================] - 0s 394us/step - loss: 4.1216 - val_loss: 4.8579
#
# Epoch 00204: val_loss did not improve from 4.56946
# Epoch 205/1000
# 86/86 [==============================] - 0s 392us/step - loss: 3.5077 - val_loss: 4.6611
#
# Epoch 00205: val_loss did not improve from 4.56946
# Epoch 206/1000
# 86/86 [==============================] - 0s 400us/step - loss: 4.2243 - val_loss: 4.9648
#
# Epoch 00206: val_loss did not improve from 4.56946
# Epoch 207/1000
# 86/86 [==============================] - 0s 384us/step - loss: 3.7394 - val_loss: 5.0361
#
# Epoch 00207: val_loss did not improve from 4.56946
# Epoch 208/1000
# 86/86 [==============================] - 0s 394us/step - loss: 4.0289 - val_loss: 5.1463
#
# Epoch 00208: val_loss did not improve from 4.56946
# Epoch 209/1000
# 86/86 [==============================] - 0s 385us/step - loss: 4.2555 - val_loss: 5.1303
#
# Epoch 00209: val_loss did not improve from 4.56946
# Epoch 210/1000
# 86/86 [==============================] - 0s 361us/step - loss: 5.1261 - val_loss: 4.7077
#
# Epoch 00210: val_loss did not improve from 4.56946
# Epoch 211/1000
# 86/86 [==============================] - 0s 384us/step - loss: 5.0391 - val_loss: 4.6341
#
# Epoch 00211: val_loss did not improve from 4.56946
# Epoch 212/1000
# 86/86 [==============================] - 0s 390us/step - loss: 5.3864 - val_loss: 4.2231
#
# Epoch 00212: val_loss improved from 4.56946 to 4.22307, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 213/1000
# 86/86 [==============================] - 0s 382us/step - loss: 4.0681 - val_loss: 4.0724
#
# Epoch 00213: val_loss improved from 4.22307 to 4.07239, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 214/1000
# 86/86 [==============================] - 0s 353us/step - loss: 3.4725 - val_loss: 3.7591
#
# Epoch 00214: val_loss improved from 4.07239 to 3.75913, saving model to ./models/01/PostOp-SNL/model_9.h5
# Epoch 215/1000
# 86/86 [==============================] - 0s 345us/step - loss: 6.2725 - val_loss: 5.4663
#
# Epoch 00215: val_loss did not improve from 3.75913
# Epoch 216/1000
# 86/86 [==============================] - 0s 375us/step - loss: 4.4674 - val_loss: 5.6033
#
# Epoch 00216: val_loss did not improve from 3.75913
# Epoch 217/1000
# 86/86 [==============================] - 0s 386us/step - loss: 4.9964 - val_loss: 5.1551
#
# Epoch 00217: val_loss did not improve from 3.75913
# Epoch 218/1000
# 86/86 [==============================] - 0s 386us/step - loss: 4.1025 - val_loss: 4.7434
#
# Epoch 00218: val_loss did not improve from 3.75913
# Epoch 219/1000
# 86/86 [==============================] - 0s 393us/step - loss: 3.1612 - val_loss: 4.4329
#
# Epoch 00219: val_loss did not improve from 3.75913
# Epoch 220/1000
# 86/86 [==============================] - 0s 403us/step - loss: 3.8621 - val_loss: 4.5426
#
# Epoch 00220: val_loss did not improve from 3.75913
# Epoch 221/1000
# 86/86 [==============================] - 0s 360us/step - loss: 3.3714 - val_loss: 4.6087
#
# Epoch 00221: val_loss did not improve from 3.75913
# Epoch 222/1000
# 86/86 [==============================] - 0s 384us/step - loss: 3.3778 - val_loss: 5.1696
#
# Epoch 00222: val_loss did not improve from 3.75913
# Epoch 223/1000
# 86/86 [==============================] - 0s 373us/step - loss: 3.1216 - val_loss: 5.6481
#
# Epoch 00223: val_loss did not improve from 3.75913
# Epoch 224/1000
# 86/86 [==============================] - 0s 377us/step - loss: 2.7449 - val_loss: 4.9648
#
# Epoch 00224: val_loss did not improve from 3.75913
# Epoch 225/1000
# 86/86 [==============================] - 0s 393us/step - loss: 4.6860 - val_loss: 5.1936
#
# Epoch 00225: val_loss did not improve from 3.75913
# Epoch 226/1000
# 86/86 [==============================] - 0s 375us/step - loss: 3.0170 - val_loss: 5.0030
#
# Epoch 00226: val_loss did not improve from 3.75913
# Epoch 227/1000
# 86/86 [==============================] - 0s 370us/step - loss: 4.6352 - val_loss: 5.4109
#
# Epoch 00227: val_loss did not improve from 3.75913
# Epoch 228/1000
# 86/86 [==============================] - 0s 376us/step - loss: 3.8695 - val_loss: 5.6410
#
# Epoch 00228: val_loss did not improve from 3.75913
# Epoch 229/1000
# 86/86 [==============================] - 0s 385us/step - loss: 4.0667 - val_loss: 4.6030
#
# Epoch 00229: val_loss did not improve from 3.75913
# Epoch 230/1000
# 86/86 [==============================] - 0s 376us/step - loss: 4.6685 - val_loss: 4.9496
#
# Epoch 00230: val_loss did not improve from 3.75913
# Epoch 231/1000
# 86/86 [==============================] - 0s 354us/step - loss: 3.5938 - val_loss: 4.8208
#
# Epoch 00231: val_loss did not improve from 3.75913
# Epoch 232/1000
# 86/86 [==============================] - 0s 392us/step - loss: 3.7269 - val_loss: 4.4828
#
# Epoch 00232: val_loss did not improve from 3.75913
# Epoch 233/1000
# 86/86 [==============================] - 0s 371us/step - loss: 2.2266 - val_loss: 4.6461
#
# Epoch 00233: val_loss did not improve from 3.75913
# Epoch 234/1000
# 86/86 [==============================] - 0s 379us/step - loss: 3.7765 - val_loss: 5.0788
#
# Epoch 00234: val_loss did not improve from 3.75913
# Epoch 00234: early stopping
# Epoch 1/1
# 86/86 [==============================] - 0s 121us/step - loss: 2.5317

# %%
accuracies = []

prediction_tag = 'PostOp-SNR'
for k in range(num_k):
    train_df = pd.read_csv(os.path.join(kfold_data_dir, f'{file_train_start}_{k}.csv',)).dropna()
    test_df = pd.read_csv(os.path.join(kfold_data_dir, f'{file_test_start}_{k}.csv')).dropna()
    
    # Create right side model
    
    x_train, y_train = get_x_and_y(train_df, feature_right, [prediction_tag])
    x_test, y_test = get_x_and_y(test_df, feature_right, [prediction_tag])
    
    x_train = np.array(x_train)
    y_train = np.array(y_train)
    
    x_test = np.array(x_test)
    y_test = np.array(y_test)
    
    model_path = os.path.join(os.path.join(models_dir, model_tag, prediction_tag, 'model_' + str(k) + '.h5'))
    
    if not os.path.exists(os.path.join(logs_dir, model_tag, prediction_tag, str(k))):
        os.mkdir(os.path.join(logs_dir, model_tag, prediction_tag, str(k)))
        
    log_path = os.path.join(os.path.join(logs_dir, model_tag, prediction_tag, str(k)))
    
    
    model = create_model(len(x_train[0]))
    history = model.fit(x_train, y_train,
                        batch_size=8,
                        epochs=1000,
                        callbacks=get_callbacks(model_path, log_path),
                        validation_data=[x_test, y_test])

    model.fit(x_train, y_train)
    model.load_weights(model_path)
    accuracies.append(get_accuracy(model, x_test, y_test))

# print(sum(result) / len(result))
# Out:
# './logs/01/PostOp-SNL'

# %%
# Out:
# 1.1320543
