# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import re

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import preprocessing
import seaborn as sns

# %%
data_dir = 'data'
df = pd.read_csv(os.path.join(data_dir, 'cleaned.csv'))
df = df.dropna()

# %%
file_train_start = 'train'
file_test_start = 'test'

predict_class_right = ['PostOp-SNR',  'PostOp-CNR',  'PostOp-BWR', 'PostOp-IMFR',  'PostOp-AreRW', 'PostOp-AreRH']

predict_class_left = [ 'PostOp-SNL',  'PostOp-CNL', 'PostOp-BWR', 'PostOp-IMFL','PostOp-AreLW', 'PostOp-AreLH']

predict_post_id = ['PostOp-ID']

feature_left = ['PreOp-SNL', 'PreOp-CNL', 'PreOp-BWL', 'PreOp-IMFL', 'PreOp-AreLW',
                'PreOp-AreLH', 'PreOp-ID', 'ImplantLeft']

feature_right = ['PreOp-SNR', 'PreOp-CNR', 'PreOp-BWR', 'PreOp-IMFR', 'PreOp-AreRW',
                'PreOp-AreRH', 'PreOp-ID', 'ImplantRight']

print(f'Number of model is {(len(predict_class_right) + len(predict_post_id) + len(predict_class_left))}')
# Out:
# Number of model is 13

# %%
def get_x_and_y(df: pd.DataFrame, x_head=[], y_head=[]):
    x, y = [], []
    
    for index, row in df.iterrows():
        x_temp = []
        for x_h in x_head:
            x_temp.append(row[x_h])
        x.append(x_temp)
        y.append(row[y_head[0]])
    
    return x, y

# %% [markdown]
# #  Feature Importance

# %%
print('Post SNR')
x, y = get_x_and_y(df, feature_right, ['PostOp-SNR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post SNR
# [0.18791833 0.16575588 0.13750031 0.14295059 0.09507471 0.07613507
#  0.08400396 0.11066114]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post CNR')
x, y = get_x_and_y(df, feature_right, ['PostOp-CNR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post CNR
# [0.15925801 0.19932794 0.13530146 0.12322932 0.10271522 0.07581451
#  0.08746456 0.11688898]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post BWR')
x, y = get_x_and_y(df, feature_right, ['PostOp-BWR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post BWR
# [0.14403133 0.12383575 0.16893264 0.14012924 0.10910531 0.09260077
#  0.09650844 0.12485651]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post IMFR')
x, y = get_x_and_y(df, feature_right, ['PostOp-IMFR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post IMFR
# [0.14293915 0.12420723 0.17585511 0.13977847 0.11667523 0.09123103
#  0.08074527 0.1285685 ]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post AreRW')
x, y = get_x_and_y(df, feature_right, ['PostOp-AreRW'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post AreRW
# [0.11937077 0.130803   0.13374401 0.12162163 0.14697065 0.10738769
#  0.10735593 0.13274632]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post AreRH')
x, y = get_x_and_y(df, feature_right, ['PostOp-AreRH'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post AreRH
# [0.11370906 0.12024103 0.11939808 0.12492823 0.1690776  0.14297583
#  0.10500625 0.10466392]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post SNL')
x, y = get_x_and_y(df, feature_left, ['PostOp-SNL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post SNL
# [0.18708895 0.1882009  0.13255526 0.12602746 0.0990344  0.07628461
#  0.07257566 0.11823276]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post CNL')
x, y = get_x_and_y(df, feature_left, ['PostOp-CNL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post CNL
# [0.18890769 0.16777939 0.14348598 0.12238343 0.0940091  0.08613794
#  0.08353292 0.11376354]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post CNL')
x, y = get_x_and_y(df, feature_left, ['PostOp-CNL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post CNL
# [0.20738504 0.15798716 0.16469955 0.129449   0.08255129 0.06848385
#  0.0751392  0.1143049 ]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post BWL')
x, y = get_x_and_y(df, feature_left, ['PostOp-BWL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post BWL
# [0.13199365 0.13185667 0.15325909 0.144726   0.09762833 0.08236312
#  0.11439605 0.14377709]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post IMFL')
x, y = get_x_and_y(df, feature_left, ['PostOp-IMFL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post IMFL
# [0.1212187  0.14719599 0.14858876 0.16645672 0.11695297 0.09445944
#  0.07497717 0.13015025]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post AreLW')
x, y = get_x_and_y(df, feature_left, ['PostOp-AreLW'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post AreLW
# [0.12697889 0.13652328 0.15463801 0.11301591 0.11833462 0.10648522
#  0.09050436 0.1535197 ]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post AreLH')
x, y = get_x_and_y(df, feature_left, ['PostOp-AreLH'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post AreLH
# [0.13084422 0.13089305 0.15314783 0.1267784  0.10234749 0.13587723
#  0.11516595 0.10494583]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
print('Post ID')
x, y = get_x_and_y(df, feature_left + feature_right, ['PostOp-ID'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

model = ExtraTreesClassifier()
model.fit(x, training_scores_encoded)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=feature_left + feature_right)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# Post ID
# [0.06519403 0.06891658 0.08469245 0.08482684 0.06152605 0.03073827
#  0.06138801 0.05165922 0.07554809 0.0636386  0.06711905 0.0809479
#  0.04889315 0.04658254 0.05470441 0.05362484]
# C:\Users\Natthawat\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %% [markdown]
# ## Correlation Matrix with Heatmap

# %%
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %% [markdown]
# ## Univariate Selection

# %%
print('Post SNR')
x, y = get_x_and_y(df, feature_right, ['PostOp-SNR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_right),'Score'))  #print 10 best features
# Out:
# Post SNR
#           Specs       Score
# 7  ImplantRight  110.524743
# 1     PreOp-CNR   15.317502
# 0     PreOp-SNR   13.023598
# 3    PreOp-IMFR    9.762565
# 5   PreOp-AreRH    9.579807
# 4   PreOp-AreRW    6.740570
# 2     PreOp-BWR    0.936211
# 6      PreOp-ID    0.610850

# %%
print('Post CNR')
x, y = get_x_and_y(df, feature_right, ['PostOp-CNR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_right),'Score'))  #print 10 best features
# Out:
# Post CNR
#           Specs      Score
# 7  ImplantRight  82.546281
# 1     PreOp-CNR  15.861801
# 0     PreOp-SNR  13.056137
# 5   PreOp-AreRH   9.856932
# 3    PreOp-IMFR   8.759872
# 4   PreOp-AreRW   6.832014
# 2     PreOp-BWR   0.909740
# 6      PreOp-ID   0.656903

# %%
print('Post BWR')
x, y = get_x_and_y(df, feature_right, ['PostOp-BWR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_right),'Score'))  #print 10 best features
# Out:
# Post BWR
#           Specs       Score
# 7  ImplantRight  154.395546
# 3    PreOp-IMFR   10.951219
# 1     PreOp-CNR    9.621406
# 0     PreOp-SNR    8.366026
# 5   PreOp-AreRH    8.185354
# 4   PreOp-AreRW    7.147897
# 6      PreOp-ID    2.144763
# 2     PreOp-BWR    1.140204

# %%
print('Post IMFR')
x, y = get_x_and_y(df, feature_right, ['PostOp-IMFR'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_right),'Score'))  #print 10 best features
# Out:
# Post IMFR
#           Specs       Score
# 7  ImplantRight  162.243717
# 3    PreOp-IMFR   11.214625
# 5   PreOp-AreRH    8.500803
# 4   PreOp-AreRW    5.680910
# 1     PreOp-CNR    5.284266
# 0     PreOp-SNR    4.355021
# 6      PreOp-ID    0.557216
# 2     PreOp-BWR    0.515431

# %%
print('Post AreRW')
x, y = get_x_and_y(df, feature_right, ['PostOp-AreRW'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_right),'Score'))  #print 10 best features
# Out:
# Post AreRW
#           Specs      Score
# 7  ImplantRight  55.683881
# 5   PreOp-AreRH  15.334447
# 4   PreOp-AreRW  13.099688
# 3    PreOp-IMFR   7.827657
# 1     PreOp-CNR   6.958071
# 0     PreOp-SNR   4.800435
# 6      PreOp-ID   1.102846
# 2     PreOp-BWR   0.564264

# %%
print('Post AreRH')
x, y = get_x_and_y(df, feature_right, ['PostOp-AreRH'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_right),'Score'))  #print 10 best features
# Out:
# Post AreRH
#           Specs      Score
# 7  ImplantRight  83.678276
# 5   PreOp-AreRH  15.239433
# 4   PreOp-AreRW  12.246505
# 3    PreOp-IMFR   7.530568
# 1     PreOp-CNR   6.691808
# 0     PreOp-SNR   5.336002
# 6      PreOp-ID   0.712596
# 2     PreOp-BWR   0.493870

# %%
print('Post SNL')
x, y = get_x_and_y(df, feature_left, ['PostOp-SNL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_left))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_left)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_left),'Score'))  #print 10 best features
# Out:
# Post SNL
#          Specs       Score
# 7  ImplantLeft  111.193095
# 1    PreOp-CNL   14.807577
# 0    PreOp-SNL   12.692387
# 3   PreOp-IMFL    8.026644
# 5  PreOp-AreLH    6.760243
# 4  PreOp-AreLW    5.013504
# 2    PreOp-BWL    0.932281
# 6     PreOp-ID    0.504490

# %%
print('Post CNL')
x, y = get_x_and_y(df, feature_left, ['PostOp-CNL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_left))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_left)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_left),'Score'))  #print 10 best features
# Out:
# Post CNL
#          Specs       Score
# 7  ImplantLeft  120.186652
# 1    PreOp-CNL   15.760975
# 0    PreOp-SNL   13.022326
# 3   PreOp-IMFL    8.292300
# 5  PreOp-AreLH    7.901591
# 4  PreOp-AreLW    6.807303
# 2    PreOp-BWL    0.907884
# 6     PreOp-ID    0.505062

# %%
print('Post IMFL')
x, y = get_x_and_y(df, feature_left, ['PostOp-IMFL'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_left))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_left)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_left),'Score'))  #print 10 best features
# Out:
# Post IMFL
#          Specs       Score
# 7  ImplantLeft  121.633676
# 3   PreOp-IMFL   11.184006
# 5  PreOp-AreLH    7.557869
# 4  PreOp-AreLW    4.768247
# 1    PreOp-CNL    4.012517
# 0    PreOp-SNL    3.268456
# 6     PreOp-ID    0.570532
# 2    PreOp-BWL    0.252532

# %%
print('Post AreLW')
x, y = get_x_and_y(df, feature_left, ['PostOp-AreLW'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_left))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_left)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_left),'Score'))  #print 10 best features
# Out:
# Post AreLW
#          Specs      Score
# 7  ImplantLeft  65.747626
# 5  PreOp-AreLH  14.760197
# 4  PreOp-AreLW  12.953663
# 3   PreOp-IMFL   7.264861
# 1    PreOp-CNL   5.607278
# 0    PreOp-SNL   4.085293
# 6     PreOp-ID   1.845096
# 2    PreOp-BWL   0.494892

# %%
print('Post AreLH')
x, y = get_x_and_y(df, feature_left, ['PostOp-AreLH'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_left))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_left)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_left),'Score'))  #print 10 best features
# Out:
# Post AreLH
#          Specs      Score
# 7  ImplantLeft  87.762565
# 5  PreOp-AreLH  14.558410
# 4  PreOp-AreLW  11.200686
# 3   PreOp-IMFL   7.909863
# 1    PreOp-CNL   7.750221
# 0    PreOp-SNL   6.523053
# 6     PreOp-ID   1.564761
# 2    PreOp-BWL   0.619414

# %%
print('Post ID')
x, y = get_x_and_y(df, feature_left + feature_right, ['PostOp-ID'])
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=len(feature_left + feature_right))
fit = bestfeatures.fit(x, training_scores_encoded)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(feature_left + feature_right)

featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(len(feature_left + feature_right),'Score'))  #print 10 best features
# Out:
# Post ID
#            Specs      Score
# 7    ImplantLeft  39.882222
# 15  ImplantRight  27.795043
# 8      PreOp-SNR   1.772901
# 0      PreOp-SNL   1.123009
# 9      PreOp-CNR   1.113894
# 1      PreOp-CNL   1.099966
# 6       PreOp-ID   1.092926
# 14      PreOp-ID   1.092926
# 4    PreOp-AreLW   1.086082
# 12   PreOp-AreRW   1.042316
# 13   PreOp-AreRH   0.915538
# 3     PreOp-IMFL   0.775949
# 11    PreOp-IMFR   0.675068
# 5    PreOp-AreLH   0.586272
# 10     PreOp-BWR   0.076263
# 2      PreOp-BWL   0.070449
